# %%
import pdfplumber
import os
import re

# %%
mode = 0o666
flags = os.O_RDWR
file_path = 'input.pdf'
tables= []
listToStr = ''

# %%
import pandas as pd
data = pd.DataFrame()

# %%
with open('table_output.txt', 'a+') as output:
    with pdfplumber.open('./input_data/2001.pdf') as pdf:
        pages = pdf.pages
        print(len(pages))
        for i, page in enumerate(pages, start=257):
            constitution_crop = pages[i].crop((200, 80, 400, 120))
            constitution_name = constitution_crop.extract_text()
            if i < 300:
                tbl = pages[i].extract_tables(table_settings={
                    "vertical_strategy": "text",
                    "horizontal_strategy": "lines",
                    "min_words_horizontal": 1,
                    "keep_blank_chars": True,
                    "text_x_tolerance": 10
                })
                #listToStr = ' '.join(map(str, tbl))
                #if i == 263
                #data.concat(pd.DataFrame(tbl,columns =["CANDIDATE NAME","SEX","AGE","CATEGORY","PARTY","GENERAL", "POSTAL","TOTAL"]))
                #tables.append(tbl)
                #else:
                #    data.
        constituency = {constitution_name:tbl}
                #output.write(str(constituency))
                #listToStr = ' '.join(map(str, tables))
# Out:
# 306
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-42a77e9cb75d> in <module>
#       4         print(len(pages))
#       5         for i, page in enumerate(pages, start=257):
# ----> 6             constitution_crop = pages[i].crop((200, 80, 400, 120))
#       7             constitution_name = constitution_crop.extract_text()
#       8             if i < 300:
#
# IndexError: list index out of range

# %%
constituency

# %%
data

# %%
 p0 = pdf.pages[257]
im = p0.to_image()      
table_settings = {
    "vertical_strategy": "text",
    "horizontal_strategy": "text",
    "min_words_horizontal":4,
    "keep_blank_chars": False,
    "text_x_tolerance": 10
}
im.reset().debug_tablefinder(table_settings)

# %%
constitution_crop = p0.crop((200, 80, 400, 120))
constitution_crop.to_image()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-b2f8254179b3> in <module>
# ----> 1 constitution_crop = p0.crop((200, 80, 400, 120))
#       2 constitution_crop.to_image()
#
# NameError: name 'p0' is not defined

# %%
constitution_crop.extract_text()
# Out:
# 'IDATE SEX\nAPRASAD.K.P M\nAN.C M'

# %%
3.SRINIVASAN

# %%
import re
m = re.search('([^\d .]]', '2. HARBOUR')
m.group(0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-7127ff0128c7> in <module>
#       1 import re
# ----> 2 m = re.search('([^\d .]]', '2. HARBOUR')
#       3 m.group(0)
#
# c:\users\bala\appdata\local\programs\python\python38\lib\re.py in search(pattern, string, flags)
#     199     """Scan through string looking for a match to the pattern, returning
#     200     a Match object, or None if no match was found."""
# --> 201     return _compile(pattern, flags).search(string)
#     202
#     203 def sub(pattern, repl, string, count=0, flags=0):
#
# c:\users\bala\appdata\local\programs\python\python38\lib\re.py in _compile(pattern, flags)
#     302     if not sre_compile.isstring(pattern):
#     303         raise TypeError("first argument must be string or compiled pattern")
# --> 304     p = sre_compile.compile(pattern, flags)
#     305     if not (flags & DEBUG):
# ...
